# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
telefonRehberi = {"Ahmet": 5326781319,"Mehmet":55}
isim = input("Lutfen numarasini ogrenmek istediginiz kisinin adini girin: ")
if isim in telefonRehberi:
    print(f"{isim} isimli kisinin numarasi su sekildedir {telefonRehberi["Ahmet"]}")
else:
    print("Boyle biri telefon rehberinde bulunamadi.")
# Out:
# Ahmet isimli kisinin numarasi su sekildedir 5326781319

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
sirketCalisanlari = {"Mehmet Yagiz":["Adana",40,"Direktor"],"Ahmet" : ["Bursa",26,"Engineer"]}
calisaninIsmi = input("Lutfen bilgilerini goruntulemek istediginiz calisanin ismini girin: ")

if calisaninIsmi in sirketCalisanlari:
    print(f"{calisaninIsmi} = {sirketCalisanlari[calisaninIsmi]}")
else:
    print("Boyle bir calisan bulunamadi.")
# Out:
# Mehmet Yagiz = ['Adana', 40, 'Direktor']

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
notlarSozlugu = {"Ahmet":[50,60,70],"Mehmet":[72,66,48],"Salih":[80,100,80]}
isim = input("Lutfen notlarini gormek istediginiz ogrencinin adini girin: ")
toplam = 0

if isim in notlarSozlugu:
    print("{} isimli ogrencinin 1.Sinav Notu : {} 2.Sinav Notu: {} 3.Sinav Notu: {} " .format(isim,notlarSozlugu[isim][0],notlarSozlugu[isim][1],notlarSozlugu[isim][2]))
    for i in notlarSozlugu[isim]:
        toplam += i
    print("Not ortlamasi : ",toplam/len(notlarSozlugu[isim]))

else:
    print("Boyle bir ogrenci bulunamadi.")
# Out:
# Mehmet isimli ogrencinin 1.Sinav Notu : 72 2.Sinav Notu: 66 3.Sinav Notu: 48
# Not ortlamasi :  62.0

# %% [markdown]
# # Problem 4

# %%
# 6-  Listenin ilk 3 elemanını alın.

# 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.

# 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.

# 9- Listenin son elemanını silin.

# 10- Liste elemanlarını tersten yazdırınız.

# 11- Aşağıdaki verileri bir liste içinde saklayınız. 

      # studentA: Yiğit Bilgi 2010, (70,60,70)
      # studentB: Sena Turan  1999, (80,80,70)
      # studentC: Ahmet Turan 1998, (80,70,90) 



# 12- Liste elemanlarını ekrana yazdırınız.



  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

# 13-  "Cenk" ismini listenin sonuna ekleyiniz.


# 14-  "Sena" değerini listenin başına ekleyiniz.


# 15-  "Deniz" ismini listeden siliniz.


# 16-  "Ali" listenin bir elemanı mıdır ?

# 17-  Liste elemanlarını ters çevirin.

# 18-  Liste elemanlarını alfabetik olarak sıralayınız.


# 19-  years listesini rakamsal büyüklüğe göre sıralayınız.

# 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.


# 21- years dizisinde kaç tane 1998 değeri vardır ?


# 22- years dizisinin tüm elemanlarını siliniz.


# 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.

# %%
liste = ["Bmw", "Mercedes", "Opel", "Mazda"]
elemanSayisi = len(liste)
print("Eleman sayisi %d" %(elemanSayisi))
print("Listenin ilk elemani {} son elemani {}".format(liste[0],liste[len(liste)-1]))
liste[-1] = "Toyota"
print(liste)
print(liste[-2])
ilkUcEleman = liste[:len(liste)-1]
print(ilkUcEleman)
ilkUcEleman[1:] = ["Toyota","Renault"]
print(ilkUcEleman)
ilkUcEleman.append("Audi")
ilkUcEleman.append("Nissan")
ilkUcEleman.remove("Nissan")
print(ilkUcEleman)
ilkUcEleman.reverse()
print(ilkUcEleman)



bilgiler = ["Yiğit Bilgi" ,2010, (70,60,70),
      "Sena Turan"  ,1999, (80,80,70),
       "Ahmet Turan", 1998, (80,70,90)]
print(bilgiler)










names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]
names.append("Cenk")
names.insert(0,"Sena")
names.remove("Deniz")
print(names)

print("Ali" in names)

names.reverse()
print(names)

siralanmis = sorted(names)
print(siralanmis)

#Rakamsal buyukluge gore siralama

for i in range(len(years)):
    for j in range(3):
        if(years[j] < years[j+1]):
            gecici = years[j]
            years[j] = years[j+1]
            years[j+1] = gecici
print(years)

str = "Chevrolet,Dacia" 

listeyeCevrilmisHali = str.split(",")
print(listeyeCevrilmisHali)

sayac = 0
for i in years:
    if(i == 1998):
        sayac+=1
print("Years listesinde %d tane 1998 sayisi vardir." %(sayac))
years.clear()
print(years)

marka1 = input("Marka 1 :")
marka2 = input("Marka 2 :")
marka3 = input("Marka 3 :")
markalar = []
markalar.append(marka1)
markalar.append(marka2)
markalar.append(marka3)
print(markalar)
# Out:
# Eleman sayisi 4
# Listenin ilk elemani Bmw son elemani Mazda
# ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# Opel
# ['Bmw', 'Mercedes', 'Opel']
# ['Bmw', 'Toyota', 'Renault']
# ['Bmw', 'Toyota', 'Renault', 'Audi']
# ['Audi', 'Renault', 'Toyota', 'Bmw']
# ['Yiğit Bilgi', 2010, (70, 60, 70), 'Sena Turan', 1999, (80, 80, 70), 'Ahmet Turan', 1998, (80, 70, 90)]
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# True
# ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# ['Ali', 'Cenk', 'Hakan', 'Sena', 'Yağmur']
# [2000, 1998, 1998, 1987]
# ['Chevrolet', 'Dacia']
# Years listesinde 2 tane 1998 sayisi vardir.
# []
# ['Audi', 'Range Rover', 'Ford']
